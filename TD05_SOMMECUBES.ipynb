# %% [markdown]
# # <center><span style="color:red;font-weight: bold">TD05 - Somme des cubes</span></center>
#
# Maintenant que les fonctions/procédures sont connues, on va pouvoir attaquer les TDs avec :
# * les entrées/sorties ;
# * les tests ;
# * les boucles ;
# * les listes (ou tableaux) ;
# * les fonctions et procédures !

# %% [markdown]
# # Partie A : Préparation et calculs
#
# On considère un entier $N \geqslant 1$, par exemple $128$. Si on additionne les cubes des chiffres composant $128$, on trouve $521$ :
#
# $$1^3+2^3+8^3=521.$$
#
# Le but de ce TD est d'étudier les propriétés de ce procédé lorsqu'on le répète plusieurs fois à la suite.

# %% [markdown]
# **Question 1**
#
# Déterminer la somme des cubes (successifs) de $2543$.<br>
# Déterminer la somme des cubes (successifs) de $371$. Que remarque-t-on ?

# %% [markdown]
# **Réponses**

# %% [markdown]
# **Propriété**
#
# Si un entier $N$ est divisible par $3$ et si on applique un certain nombre de fois la somme des cubes à partir de cet entier $N$, on obtient toujours $153$.
#
# Pour un entier vérifiant cette propriété, on appelle **vol de l'entier** $N$ la suite de nombres obtenue jusqueà l'obtention du premier nombre $153$.
#
# Par exemple le vol de $9$ est noté $V_9$ :
#
# $$9 \rightarrow 729 \rightarrow 1080 \rightarrow 513 \rightarrow 153.$$

# %% [markdown]
# **Question 2**
#
# Déterminer le vol de l'entier $72$.<br>
# Déterminer le vol de l'entier $132$.<br>
# Déterminer une entier dont le vol a une longueur $3$ (la suite comporte $3$ nombres).

# %% [markdown]
# **Réponses**

# %% [markdown]
# # Partie B : Algorithmique et Python

# %% [markdown]
# **Question 3**
#
# Compléter (les ....) l'algorithme suivant à l'aide des fonctions suivantes :
# * len(objet) : donne la longueur de l'objet
# * int(chaine) : convertit la chaîne en entier
# * str(objet) : convertit l'objet en chaîne de caractères
#
# <blockquote>ALGORITHME 1<br>
# n ← Saisir("Entrer une valeur d'entier : ")<br>
# nchaine ← ....... # conversion de l'entier en chaîne de caractères<br>
# longueur ← ....... # longueur de la chaîne<br>
# somme ← 0<br>
# Pour i allant de 0 à longueur-1 faire :<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;ch ← ...(nchaine[i]) # conversion du caractère nchaine[i] en entier<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;somme ← somme + ch**3<br>
# FinPour<br>
# Afficher(somme)</blockquote>

# %% [markdown]
# **Question 4**
#
# Transformer cet algorithme en une ***fonction*** _sommecubes(n)_ qui prend un entier _n_ en argument et ***renvoie*** la somme des cubes de ses chiffres.

# %%
# Question 4

def sommescubes(n):
    nchaine = 
    
    
    return somme

# %%
sommescubes(702)

# %% [markdown]
# **Question 5**
#
# Écrire une **fonction** _volcubes(n)_ qui prend en paramètre un entier _n_ et qui teste s'il est divisible par $3$ et :
# * si l'entier n'est pas divisible par $3$, la fonction ***renvoie*** "Cet entier ne convient pas car il n'est pas divisible par $3$" ;
# * sinon, la fonction ***renvoie*** le vol du nombre, c'est-à-dire la **liste** des valeurs successives des sommes de cubes, jusqu'à atteindre la valeur $153$.

# %%
# Question 5

def volcubes(n):
    if n%3 != 0:
        return "Cet entier ne convient pas car il n'est pas divisible par 3 !"
    else :
        
        return L

# %%
volcubes(9)

# %% [markdown]
# **Question 6**
#
# Écrire une procédure _liste()_ qui affiche tous les vols des entiers divisibles par $3$ inférieurs ou égaux à un entier donné _n_.

# %%
# Question 6

def liste(n) :
    L=[]
    for i in range(1,n+1):
        if i%3 == 0:

# %%
liste(25)

# %% [markdown]
# **Question 7**
#
# Quelle est la plus grande longueur de vol pour les nombres inférieurs ou égaux à $10\,000$, c'est-à-dire la liste la plus longue donnée par la fonction précédente ? Donner un exemple d'entier ayant cette longueur de vol.

# %%
# Question 7

def volmax(n) :
    maxi = 1
    for i in range(1,n+1):
        if i%3 == 0 and len(volcubes(i)) > maxi :
            maxi = .........
            volmaxi = .........
    print(f"Le vol le plus long est de longueur {maxi}")
    print(f"Par exemple avec N={volmaxi[0]} : {volmaxi}")

# %%
volmax(10000)
print("-------")
volmax2(10000)
print("-------")
volmax2(100000)
